# %%
# https://www.planet.com/data/stac/browser/education/brandenburg/2024-08-13_analysis_ready_ps_sr.json?.asset=asset-sr

# %%
# !ls
# Out:
# 2024-08-13_analysis_ready_ps_sr.tiff  sample_data

# %%
# !pip install rasterio matplotlib numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 49.7 MB/s eta 0:00:00
# ...

# %%
# !pip install imagecodecs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 21.0 MB/s eta 0:00:00
# ...

# %%
import rasterio
import matplotlib.pyplot as plt

with rasterio.open(sample_data_file_name) as src:
    red = src.read(3)
    green = src.read(2)
    blue = src.read(1)

# Scale if needed (Planet data usually needs scaling by 0.0001)
rgb = (np.stack([red, green, blue], axis=-1) * 0.0001)
rgb = np.clip(rgb / 0.3, 0, 1)  # Normalize to 0-1 range for display

plt.imshow(rgb)
plt.axis('off')
plt.title('True Color Composite')
plt.show()
